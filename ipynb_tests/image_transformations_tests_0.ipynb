# %%
#Import libraries for doing image analysis
from skimage.io import imread
from sklearn.ensemble import RandomForestClassifier as RF
import glob
import os
from matplotlib import pyplot as plt
from matplotlib import colors
from pylab import cm
from skimage import segmentation
from skimage.morphology import watershed
from skimage import measure
from skimage import morphology
import numpy as np
import pandas as pd
from scipy import ndimage
from skimage.feature import peak_local_max
# make graphics inline
# %matplotlib inline

# %%
from skimage import transform as skimtr

# %%
# get the classnames from the directory structure
directory_names = list(set(glob.glob(os.path.join("../competition_data","train", "*"))\
 ).difference(set(glob.glob(os.path.join("../competition_data","train","*.*")))))

# %%
example_file = glob.glob(os.path.join(directory_names[5],"*.jpg"))[1]
print example_file
im = imread(example_file, as_grey=True)
im = resize(im, (48, 48))
# Out:
# ../competition_data/train/shrimp_zoea/10222.jpg

# %% [markdown]
# # ROTATION

# %%
im_rot = im.copy()
im_rot_resize = im.copy()
im_rot = skimtr.rotate(im_rot, 45, resize=False, cval=1.0) # if using cval=1, raw img vals maintained
im_rot_resize = skimtr.rotate(im_rot_resize, 45, resize=True, cval=im.mean()) #if using mean, centred image properties maintained

plt.imshow(im, cmap=cm.gray)
plt.show()
plt.imshow(im_rot, cmap=cm.gray)
plt.show()
plt.imshow(im_rot_resize, cmap=cm.gray)
plt.show()

# %% [markdown]
# #

# %%
# skimtr.AffineTransform()
# skimtr.PolynomialTransform()
# skimtr.hough_ellipse()
# skimtr.pyramid_gaussian()
# skimtr.rescale()
# skimtr.resize()
skimtr.
# Out:
# <module 'skimage.transform' from '/home/joth/venvs/2014-12-20_datascibowl/lib/python2.7/site-packages/skimage/transform/__init__.pyc'>

# %%
im_rot = im.copy()
im_rot_resize = im.copy()
im_rot = skimtr.rotate(im_rot, 45, resize=False, cval=1.0) # if using cval=1, raw img vals maintained
im_rot_resize = skimtr.rotate(im_rot_resize, 45, resize=True, cval=im.mean()) #if using mean, centred image properties maintained

plt.imshow(im, cmap=cm.gray)
plt.show()
plt.imshow(im_rot, cmap=cm.gray)
plt.show()
plt.imshow(im_rot_resize, cmap=cm.gray)
plt.show()
