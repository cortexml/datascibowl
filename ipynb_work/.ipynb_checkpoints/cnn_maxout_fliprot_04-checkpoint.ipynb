# %% [markdown]
# 1. Setup the yaml file
#     - data
#     - model
#     - algorithm
#     - termination criteria
#     - monitoring extensions (filename)
#     - save path (filename)
# 2. Update paths/filenames in ipython notebook
#     - print monitor of best fit
#     - prediction model and save file path
#     - gzip

# %%
import os
import pylearn2
from pylearn2.config import yaml_parse
import glob
import numpy as np
import pickle as pkl
import pandas as pd
# Out:
# Using gpu device 0: GeForce GTX 550 Ti

# %%
os.environ["PYLEARN2_DATA_PATH"] = "/home/jotham/projects/2014-12-20_datascibowl/data"
print os.path.expandvars("$PYLEARN2_DATA_PATH")
# Out:
# /home/jotham/projects/2014-12-20_datascibowl/data

# %%
with open('cnn_maxout_resample_03.yaml', 'r') as f:
    train = f.read()
save_path = '.'
train = train %locals()

# %%
print train
# Out:
# !obj:pylearn2.train.Train {
#     dataset: &train !obj:pylearn2.datasets.datascibowl.DataSciBowl {
#         which_set: 'train',
#         start: 0,
#         stop: 215513,
#         shuffle: True,
#         center: True,
# 	augment_factor: 1,
#     },
#     model: !obj:pylearn2.models.mlp.MLP {
#         batch_size: 100,
#         input_space: !obj:pylearn2.space.Conv2DSpace {
#             shape: [32, 32],
#             num_channels: 1,
#             axes: ['c', 0, 1, 'b'],
#         },
#         layers: [
#             !obj:pylearn2.models.maxout.MaxoutConvC01B {
#                 layer_name: 'h0',
#                 pad: 0,
#                 num_channels: 48,
#                 num_pieces: 2,
#                 kernel_shape: [8, 8],
#                 pool_shape: [4, 4],
#                 pool_stride: [2, 2],
#                 irange: .005,
#                 max_kernel_norm: .9,
#             },
#             !obj:pylearn2.models.maxout.MaxoutConvC01B {
# ...

# %%
# export PYLEARN2_DATA_PATH="/home/jotham/projects/2014-12-20_datascibowl/data"
# !../pylearn2_fork/pylearn2/scripts/train.py cnn_maxout_resample_03.yaml

# %%
# !../pylearn2_fork/pylearn2/scripts/print_monitor.py cnn_maxout_resample_03_best.pkl
# Out:
# Using gpu device 0: GeForce GTX 550 Ti
# epochs seen:  8
# time trained:  1856.8408041
# learning_rate : 0.0461560338736
# momentum : 0.505624353886
# total_seconds_last_epoch : 218.502258301
# train_h0_kernel_norms_max : 0.385159730911
# train_h0_kernel_norms_mean : 0.122893489897
# train_h0_kernel_norms_min : 0.0231061168015
# train_h0_max_x.max_u : 0.89766395092
# train_h0_max_x.mean_u : 0.417746603489
# train_h0_max_x.min_u : 0.113411933184
# train_h0_mean_x.max_u : 0.185140773654
# train_h0_mean_x.mean_u : 0.0842552706599
# train_h0_mean_x.min_u : -0.039699755609
# train_h0_min_x.max_u : 0.000859297346324
# train_h0_min_x.mean_u : -0.175128877163
# train_h0_min_x.min_u : -0.960364341736
# train_h0_range_x.max_u : 1.67633616924
# train_h0_range_x.mean_u : 0.592875361443
# train_h0_range_x.min_u : 0.125229030848
# train_h1_kernel_norms_max : 0.573446333408
# train_h1_kernel_norms_mean : 0.240665718913
# train_h1_kernel_norms_min : 0.159746468067
# ...

# %%
# !../pylearn2_fork/pylearn2/scripts/mlp/predict_cnn_csv.py \
    cnn_maxout_resample_03_best.pkl\
    test_data_centered_cnn_32px.npy\
    submission_cnn_maxout_transform_03_best.csv\
    pred_rownames_cnn.pkl\
    pred_colnames_reader.pkl
# Out:
# Using gpu device 0: GeForce GTX 550 Ti
# loading model...
# loading data and predicting...
# setting up symbolic expressions...
# writing predictions...

# %%
# OLD ONE WITH BUGGERED COL LABELS
y = pd.read_csv('submission_cnn_maxout_transform_03_best.csv')
y
# Out:
#              image  euphausiids_young  hydromedusae_narcomedusae  \
# 0        79469.jpg       5.081476e-06               2.673470e-10
# 1       158984.jpg       7.198077e-08               2.827061e-07
# 2       114171.jpg       6.839249e-06               8.730008e-05
# 3        56148.jpg       1.702497e-08               1.488201e-04
# 4        28082.jpg       1.195740e-08               4.425890e-10
# 5        69488.jpg       1.090891e-02               3.521917e-11
# 6       116104.jpg       2.083872e-05               7.054189e-04
# 7        35015.jpg       3.162089e-07               1.331122e-11
# 8       137664.jpg       5.595629e-05               1.929487e-11
# 9       119939.jpg       1.769059e-04               5.050132e-08
# 10       94206.jpg       3.211416e-03               2.565857e-08
# 11      160285.jpg       1.312957e-05               3.753264e-05
# 12       91834.jpg       3.845288e-06               2.626654e-08
# ...

# %%
# !gzip submission_cnn_maxout_transform_03_best.csv
